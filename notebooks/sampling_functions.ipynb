# %%
import pandas as pd
import numpy as np
import random
import io

# %% [markdown]
# ### Loading Dataset

# %%
econ_df = pd.read_csv(filepath_or_buffer="./econ.csv", sep=',', header=0)
econ_df.head(3)
# Out:
#    id                  geo_point_2d  \
# 0   0   19.424781053,-99.1327537959
# 1   1  19.4346139576,-99.1413808393
# 2   2  19.4340695945,-99.1306348409
#
#                                            geo_shape   clave_cat  delegacion  \
# 0  {"type": "Polygon", "coordinates": [[[-99.1332...  307_130_11  Cuauhtémoc
# 1  {"type": "MultiPoint", "coordinates": [[-99.14...  002_008_01   Cuautémoc
# 2  {"type": "MultiPoint", "coordinates": [[-99.13...  006_002_12   Cuautémoc
#
#   perimetro     tipo                                             nom_id
# 0         B  Mercado                                        Pino Suárez
# 1         A    Museo  Museo Nacional de Arquitectura Palacio de Bell...
# 2         A    Museo                                       Santa Teresa

# %% [markdown]
# ### Sampling functions
# #### 1. Simple random sampling

# %%
aleat_8 = econ_df.sample(n=8)
aleat_8
# Out:
#       id                  geo_point_2d  \
# 163  163  19.4265454033,-99.1224859032
# 60    60  19.4274816595,-99.1285626779
# 76    76  19.4367072434,-99.1424407474
# 132  132  19.4248733452,-99.1202942813
# 38    38  19.4439555857,-99.1345196425
# 147  147  19.4383757081,-99.1416066037
# 131  131  19.4389531509,-99.1479144659
# 69    69      19.43558625,-99.12965746
#
#                                              geo_shape   clave_cat  \
# 163  {"type": "Polygon", "coordinates": [[[-99.1231...  323_063_05
# 60   {"type": "MultiPoint", "coordinates": [[-99.12...  006_086_10
# 76   {"type": "MultiPoint", "coordinates": [[-99.14...  003_095_02
# 132  {"type": "MultiPoint", "coordinates": [[-99.12...  323_102_02
# 38   {"type": "Polygon", "coordinates": [[[-99.1351...  004_106_01
# 147  {"type": "Polygon", "coordinates": [[[-99.1416...  003_098_01
# 131  {"type": "MultiPoint", "coordinates": [[-99.14...  003_080_06
# 69   {"type": "MultiPoint", "coordinates": [[-99.12...  005_129_08
#
#               delegacion perimetro     tipo                    nom_id
# 163  Venustiano Carranza         B  Mercado                       NaN
# 60             Cuautémoc         A    Hotel                    Oviedo
# 76             Cuautémoc         A    Museo               Franz Mayer
# 132  Venustiano Carranza         B    Hotel                   De Casa
# 38            Cuauhtémoc         B  Mercado  La Lagunilla Comestibles
# 147           Cuauhtémoc         A  Mercado                2 de Abril
# 131            Cuautémoc         A    Museo   Panteón de San Fernando
# 69             Cuautémoc         A    Hotel              Templo Mayor

# %% [markdown]
# #### 2. Systematic sampling

# %%
def systematic_sampling(econ_df, step):
    systematic_sample = econ_df.iloc[:len(econ_df):step]
    return systematic_sample

# %%
systematic_sample = systematic_sampling(econ_df, 10)
systematic_sample.head() # In this case, each 3 values.
# Out:
#     id                  geo_point_2d  \
# 0    0   19.424781053,-99.1327537959
# 10  10    19.4441424478,-99.14600807
# 20  20  19.4357307042,-99.1326583218
# 30  30   19.427530818,-99.1479200065
# 40  40  19.4371002964,-99.1504966035
#
#                                             geo_shape   clave_cat  delegacion  \
# 0   {"type": "Polygon", "coordinates": [[[-99.1332...  307_130_11  Cuauhtémoc
# 10  {"type": "MultiPoint", "coordinates": [[-99.14...  003_048_10   Cuautémoc
# 20  {"type": "MultiPoint", "coordinates": [[-99.13...  004_098_26   Cuautémoc
# 30  {"type": "MultiPoint", "coordinates": [[-99.14...  002_068_13   Cuautémoc
# 40  {"type": "MultiPoint", "coordinates": [[-99.15...  011_291_35   Cuautémoc
#
#    perimetro     tipo                                         nom_id
# 0          B  Mercado                                    Pino Suárez
# 10         B    Hotel                                      Moctezuma
# 20         A    Museo                                  La Caricatura
# 30         B    Hotel                                      Villa Pal
# 40         B    Hotel  Servicios Hoteleros de tlaxcala, S.A. DE C.V.

# %% [markdown]
# #### 4. Stratified random sampling.

# %%
econ_df['stratified'] = econ_df['delegacion'] + ", " + econ_df['tipo']
(econ_df['stratified'].value_counts()/len(econ_df)).sort_values(ascending=False)
# Out:
# Cuautémoc, Hotel                0.643478
# Cuautémoc, Museo                0.156522
# Venustiano Carranza, Hotel      0.078261
# Cuauhtémoc, Mercado             0.073913
# Venustiano Carranza, Mercado    0.047826
# Name: stratified, dtype: float64

# %%
def data_stratified(econ_df, strat_column_values, strat_values, strat_prop, random_state=None):
    df_strat = pd.DataFrame(columns = econ_df.columns)
    pos = -1
    for i in range(len(strat_values)):
        pos += 1
        if pos == len(strat_values) - 1:
            ratio_len = len(econ_df) - len(df_strat)
        else:
            ratio_len = int(len(econ_df) * strat_prop[i])
            
        df_filtered = econ_df[econ_df[strat_column_values] == strat_values[i]]
        df_temp = df_filtered.sample(replace=True, n=ratio_len, random_state=random_state)
        
        df_strat = pd.concat([df_strat, df_temp])
    
    return df_temp

# %%
strat_values = ['Cuautémoc, Hotel', 'Cuautémoc, Museo', 'Venustiano Carranza, Hotel', 'Cuauhtémoc, Mercado', 'Venustiano Carranza, Mercado']
strat_props = [0.5, 0.2, 0.1, 0.1, 0.1]

# %%
df_strat = data_stratified(econ_df, 'stratified', strat_values, strat_props, random_state=42)
df_strat
# Out:
#       id                  geo_point_2d  \
# 157  157  19.4272935771,-99.1227492994
# 77    77  19.4254536359,-99.1226996335
# 216  216  19.4247697438,-99.1249707246
# 163  163  19.4265454033,-99.1224859032
# 128  128  19.4270781084,-99.1210175514
# 157  157  19.4272935771,-99.1227492994
# 204  204  19.4260286762,-99.1249971994
# 49    49  19.4264953358,-99.1248854383
# 157  157  19.4272935771,-99.1227492994
# 216  216  19.4247697438,-99.1249707246
# 216  216  19.4247697438,-99.1249707246
# 163  163  19.4265454033,-99.1224859032
# 128  128  19.4270781084,-99.1210175514
# 77    77  19.4254536359,-99.1226996335
# 163  163  19.4265454033,-99.1224859032
# 163  163  19.4265454033,-99.1224859032
# 49    49  19.4264953358,-99.1248854383
# 156  156  19.4255480371,-99.1249308096
# 128  128  19.4270781084,-99.1210175514
# 37    37   19.4271233834,-99.125111772
# 163  163  19.4265454033,-99.1224859032
# 156  156  19.4255480371,-99.1249308096
# 37    37   19.4271233834,-99.125111772
#
#                                              geo_shape        clave_cat  \
# 157  {"type": "Polygon", "coordinates": [[[-99.1230...       323_063_08
# 77   {"type": "Polygon", "coordinates": [[[-99.1233...       323_101_01
# 216  {"type": "Polygon", "coordinates": [[[-99.1250...       323_118_37
# 163  {"type": "Polygon", "coordinates": [[[-99.1231...       323_063_05
# 128  {"type": "Polygon", "coordinates": [[[-99.1214...  323_061_04(123)
# 157  {"type": "Polygon", "coordinates": [[[-99.1230...       323_063_08
# 204  {"type": "Polygon", "coordinates": [[[-99.1253...       323_138_01
# 49   {"type": "Polygon", "coordinates": [[[-99.1252...       323_139_01
# 157  {"type": "Polygon", "coordinates": [[[-99.1230...       323_063_08
# 216  {"type": "Polygon", "coordinates": [[[-99.1250...       323_118_37
# 216  {"type": "Polygon", "coordinates": [[[-99.1250...       323_118_37
# 163  {"type": "Polygon", "coordinates": [[[-99.1231...       323_063_05
# 128  {"type": "Polygon", "coordinates": [[[-99.1214...  323_061_04(123)
# 77   {"type": "Polygon", "coordinates": [[[-99.1233...       323_101_01
# 163  {"type": "Polygon", "coordinates": [[[-99.1231...       323_063_05
# 163  {"type": "Polygon", "coordinates": [[[-99.1231...       323_063_05
# 49   {"type": "Polygon", "coordinates": [[[-99.1252...       323_139_01
# 156  {"type": "Polygon", "coordinates": [[[-99.1253...   323_138_04 (3)
# 128  {"type": "Polygon", "coordinates": [[[-99.1214...  323_061_04(123)
# 37   {"type": "Polygon", "coordinates": [[[-99.1251...       323_065_01
# 163  {"type": "Polygon", "coordinates": [[[-99.1231...       323_063_05
# 156  {"type": "Polygon", "coordinates": [[[-99.1253...   323_138_04 (3)
# 37   {"type": "Polygon", "coordinates": [[[-99.1251...       323_065_01
#
#               delegacion perimetro     tipo                  nom_id  \
# 157  Venustiano Carranza         B  Mercado          Merced Comidas
# 77   Venustiano Carranza         B  Mercado    La Merced Nave Menor
# 216  Venustiano Carranza         B  Mercado  Lamininas de La Merced
# 163  Venustiano Carranza         B  Mercado                     NaN
# 128  Venustiano Carranza         B  Mercado             San Ciprian
# 157  Venustiano Carranza         B  Mercado          Merced Comidas
# 204  Venustiano Carranza         B  Mercado                Florería
# 49   Venustiano Carranza         B  Mercado     Dulceria Don Goloso
# 157  Venustiano Carranza         B  Mercado          Merced Comidas
# 216  Venustiano Carranza         B  Mercado  Lamininas de La Merced
# 216  Venustiano Carranza         B  Mercado  Lamininas de La Merced
# 163  Venustiano Carranza         B  Mercado                     NaN
# 128  Venustiano Carranza         B  Mercado             San Ciprian
# 77   Venustiano Carranza         B  Mercado    La Merced Nave Menor
# 163  Venustiano Carranza         B  Mercado                     NaN
# 163  Venustiano Carranza         B  Mercado                     NaN
# 49   Venustiano Carranza         B  Mercado     Dulceria Don Goloso
# 156  Venustiano Carranza         B  Mercado                Mariscos
# 128  Venustiano Carranza         B  Mercado             San Ciprian
# 37   Venustiano Carranza         B  Mercado                Dulceria
# 163  Venustiano Carranza         B  Mercado                     NaN
# 156  Venustiano Carranza         B  Mercado                Mariscos
# 37   Venustiano Carranza         B  Mercado                Dulceria
#
#                        stratified
# 157  Venustiano Carranza, Mercado
# 77   Venustiano Carranza, Mercado
# 216  Venustiano Carranza, Mercado
# 163  Venustiano Carranza, Mercado
# 128  Venustiano Carranza, Mercado
# 157  Venustiano Carranza, Mercado
# 204  Venustiano Carranza, Mercado
# 49   Venustiano Carranza, Mercado
# 157  Venustiano Carranza, Mercado
# 216  Venustiano Carranza, Mercado
# 216  Venustiano Carranza, Mercado
# 163  Venustiano Carranza, Mercado
# 128  Venustiano Carranza, Mercado
# 77   Venustiano Carranza, Mercado
# 163  Venustiano Carranza, Mercado
# 163  Venustiano Carranza, Mercado
# 49   Venustiano Carranza, Mercado
# 156  Venustiano Carranza, Mercado
# 128  Venustiano Carranza, Mercado
# 37   Venustiano Carranza, Mercado
# 163  Venustiano Carranza, Mercado
# 156  Venustiano Carranza, Mercado
# 37   Venustiano Carranza, Mercado

# %%
econ_df['stratified'] = econ_df['delegacion'] + " - " + econ_df['tipo']

# %%
def stratified_sample( category, size, data=econ_df):
  strat_values = data[category].unique()
  strat_props = (data[category].value_counts() / len(data))

  strat_sample = pd.DataFrame(columns = data.columns)

  for value in strat_values:
    strat_sample = pd.concat([strat_sample, data[(data[category] == value)].sample(n = round(strat_props[value]*size)) ])
  
  return strat_sample

strat_sample = stratified_sample('stratified', 40)
strat_sample
# Out:
#       id                  geo_point_2d  \
# 226  226  19.4416748524,-99.1365878489
# 0      0   19.424781053,-99.1327537959
# 162  162  19.4452741596,-99.1443205075
# 207  207  19.4344738803,-99.1305689118
# 175  175  19.4291934671,-99.1323328561
# 110  110  19.4356877258,-99.1387888649
# 19    19  19.4317119617,-99.1269115285
# 2      2  19.4340695945,-99.1306348409
# 18    18  19.4331161255,-99.1309438719
# 95    95  19.4370305998,-99.1214093113
# 42    42  19.4368553413,-99.1196435872
# 115  115  19.4336966991,-99.1237253904
# 188  188  19.4281241134,-99.1460742157
# 31    31  19.4242639147,-99.1311619613
# 67    67  19.4434657626,-99.1247401574
# 220  220   19.4331382067,-99.125997696
# 112  112  19.4328570897,-99.1361965435
# 116  116      19.43339234,-99.14617457
# 180  180  19.4357633849,-99.1330511805
# 87    87  19.4397239469,-99.1461558557
# 86    86  19.4244645173,-99.1433325213
# 46    46   19.426941681,-99.1326869759
# 66    66  19.4331350004,-99.1382989213
# 101  101  19.4340314709,-99.1362576859
# 139  139  19.4331109726,-99.1250977437
# 70    70       19.43712772,-99.1378899
# 122  122  19.4328655483,-99.1385210348
# 105  105  19.4298675871,-99.1370239721
# 223  223  19.4285106481,-99.1367967407
# 213  213   19.432385153,-99.1274363518
# 200  200  19.4340073515,-99.1372646267
# 104  104      19.43397933,-99.13044075
# 165  165  19.4248396624,-99.1333096809
# 183  183      19.43807011,-99.13611488
# 133  133  19.4388860834,-99.1250947991
# 164  164  19.4388741511,-99.1413308257
# 195  195  19.4414840739,-99.1394736635
# 84    84  19.4426697365,-99.1426738122
# 37    37   19.4271233834,-99.125111772
# 156  156  19.4255480371,-99.1249308096
#
#                                              geo_shape       clave_cat  \
# 226  {"type": "Polygon", "coordinates": [[[-99.1370...      004_052_01
# 0    {"type": "Polygon", "coordinates": [[[-99.1332...      307_130_11
# 162  {"type": "Polygon", "coordinates": [[[-99.1448...      003_044_01
# 207  {"type": "MultiPoint", "coordinates": [[-99.13...      006_002_13
# 175  {"type": "MultiPoint", "coordinates": [[-99.13...      006_073_11
# 110  {"type": "MultiPoint", "coordinates": [[-99.13...      001_003_11
# 19   {"type": "MultiPoint", "coordinates": [[-99.12...      006_026_28
# 2    {"type": "MultiPoint", "coordinates": [[-99.13...      006_002_12
# 18   {"type": "MultiPoint", "coordinates": [[-99.13...      006_021_01
# 95   {"type": "MultiPoint", "coordinates": [[-99.12...      318_114_01
# 42   {"type": "MultiPoint", "coordinates": [[-99.11...      018_337_01
# 115  {"type": "MultiPoint", "coordinates": [[-99.12...      323_010_09
# 188  {"type": "MultiPoint", "coordinates": [[-99.14...      002_067_08
# 31   {"type": "MultiPoint", "coordinates": [[-99.13...      307_129_20
# 67   {"type": "MultiPoint", "coordinates": [[-99.12...      005_057_01
# 220  {"type": "MultiPoint", "coordinates": [[-99.12...      006_008_08
# 112  {"type": "MultiPoint", "coordinates": [[-99.13...      001_023_15
# 116  {"type": "MultiPoint", "coordinates": [[-99.14...      002_017_02
# 180  {"type": "MultiPoint", "coordinates": [[-99.13...      004_094_32
# 87   {"type": "MultiPoint", "coordinates": [[-99.14...      003_075_19
# 86   {"type": "MultiPoint", "coordinates": [[-99.14...      002_085_04
# 46   {"type": "MultiPoint", "coordinates": [[-99.13...      006_090_12
# 66   {"type": "MultiPoint", "coordinates": [[-99.13...      001_021_14
# 101  {"type": "MultiPoint", "coordinates": [[-99.13...      001_013_01
# 139  {"type": "MultiPoint", "coordinates": [[-99.12...      006_009_11
# 70   {"type": "MultiPoint", "coordinates": [[-99.13...      004_090_02
# 122  {"type": "MultiPoint", "coordinates": [[-99.13...      001_020_04
# 105  {"type": "MultiPoint", "coordinates": [[-99.13...      001_042_04
# 223  {"type": "MultiPoint", "coordinates": [[-99.13...      001_055_10
# 213  {"type": "MultiPoint", "coordinates": [[-99.12...      006_018_09
# 200  {"type": "MultiPoint", "coordinates": [[-99.13...      001_014_02
# 104  {"type": "MultiPoint", "coordinates": [[-99.13...      006_002_12
# 165  {"type": "MultiPoint", "coordinates": [[-99.13...      001_086_01
# 183  {"type": "MultiPoint", "coordinates": [[-99.13...      004_075_07
# 133  {"type": "MultiPoint", "coordinates": [[-99.12...      005_099_14
# 164  {"type": "MultiPoint", "coordinates": [[-99.14...      003_113_03
# 195  {"type": "MultiPoint", "coordinates": [[-99.13...      004_050_13
# 84   {"type": "MultiPoint", "coordinates": [[-99.14...      003_056_09
# 37   {"type": "Polygon", "coordinates": [[[-99.1251...      323_065_01
# 156  {"type": "Polygon", "coordinates": [[[-99.1253...  323_138_04 (3)
#
#               delegacion perimetro     tipo  \
# 226           Cuauhtémoc         B  Mercado
# 0             Cuauhtémoc         B  Mercado
# 162           Cuauhtémoc         B  Mercado
# 207            Cuautémoc         A    Museo
# 175            Cuautémoc         A    Museo
# 110            Cuautémoc         A    Museo
# 19             Cuautémoc         A    Museo
# 2              Cuautémoc         A    Museo
# 18             Cuautémoc         A    Museo
# 95   Venustiano Carranza         B    Hotel
# 42   Venustiano Carranza         B    Hotel
# 115  Venustiano Carranza         B    Hotel
# 188            Cuautémoc         B    Hotel
# 31             Cuautémoc         B    Hotel
# 67             Cuautémoc         B    Hotel
# 220            Cuautémoc         A    Hotel
# 112            Cuautémoc         A    Hotel
# 116            Cuautémoc         B    Hotel
# 180            Cuautémoc         A    Hotel
# 87             Cuautémoc         B    Hotel
# 86             Cuautémoc         B    Hotel
# 46             Cuautémoc         A    Hotel
# 66             Cuautémoc         A    Hotel
# 101            Cuautémoc         A    Hotel
# 139            Cuautémoc         A    Hotel
# 70             Cuautémoc         A    Hotel
# 122            Cuautémoc         A    Hotel
# 105            Cuautémoc         A    Hotel
# 223            Cuautémoc         A    Hotel
# 213            Cuautémoc         A    Hotel
# 200            Cuautémoc         A    Hotel
# 104            Cuautémoc         A    Hotel
# 165            Cuautémoc         B    Hotel
# 183            Cuautémoc         A    Hotel
# 133            Cuautémoc         B    Hotel
# 164            Cuautémoc         B    Hotel
# 195            Cuautémoc         B    Hotel
# 84             Cuautémoc         B    Hotel
# 37   Venustiano Carranza         B  Mercado
# 156  Venustiano Carranza         B  Mercado
#
#                                  nom_id                     stratified
# 226                          De Muebles           Cuauhtémoc - Mercado
# 0                           Pino Suárez           Cuauhtémoc - Mercado
# 162                Martínez de la Torre           Cuauhtémoc - Mercado
# 207             Autonomía Universitaria              Cuautémoc - Museo
# 175                 La Ciudad de México              Cuautémoc - Museo
# 110  Museo interactivo de economía Mide              Cuautémoc - Museo
# 19                   Alondiga La Merced              Cuautémoc - Museo
# 2                          Santa Teresa              Cuautémoc - Museo
# 18       Museo Nacional de las Culturas              Cuautémoc - Museo
# 95                                Seoul    Venustiano Carranza - Hotel
# 42                       HOTEL RRO MI1O    Venustiano Carranza - Hotel
# 115                               Antas    Venustiano Carranza - Hotel
# 188                            Manolo 1              Cuautémoc - Hotel
# 31                             Escorial              Cuautémoc - Hotel
# 67                              Sevilla              Cuautémoc - Hotel
# 220                        México Nuevo              Cuautémoc - Hotel
# 112                            Downtown              Cuautémoc - Hotel
# 116                   Monte RealL, S.A.              Cuautémoc - Hotel
# 180              Catedral, S.A. DE C.V.              Cuautémoc - Hotel
# 87                              Astoria              Cuautémoc - Hotel
# 86                             San Juan              Cuautémoc - Hotel
# 46                            Castropol              Cuautémoc - Hotel
# 66                              Coliseo              Cuautémoc - Hotel
# 101                              Gillow              Cuautémoc - Hotel
# 139                Continental Méxicano              Cuautémoc - Hotel
# 70                             Congreso              Cuautémoc - Hotel
# 122                           Principal              Cuautémoc - Hotel
# 105                              Isabel              Cuautémoc - Hotel
# 223                                Niza              Cuautémoc - Hotel
# 213                              Nevada              Cuautémoc - Hotel
# 200                        Buenos Aires              Cuautémoc - Hotel
# 104                             Palacio              Cuautémoc - Hotel
# 165                              Latino              Cuautémoc - Hotel
# 183                      Antillas, S.A.              Cuautémoc - Hotel
# 133                             Venecia              Cuautémoc - Hotel
# 164                        Dos Naciones              Cuautémoc - Hotel
# 195                           Emperador              Cuautémoc - Hotel
# 84                         Las Americas              Cuautémoc - Hotel
# 37                             Dulceria  Venustiano Carranza - Mercado
# 156                            Mariscos  Venustiano Carranza - Mercado
