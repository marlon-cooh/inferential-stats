# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %%
grades_m8 = pd.read_csv(filepath_or_buffer='../Datasets/RC_M8_GENERAL_CLASSROOM.csv', sep=',')
grades_m8
# Out:
#            Apellidos                     Nombre  \
# 0              Fecha                        NaN
# 1             Puntos                        NaN
# 2        Larez Rivas            Ainhoa Victoria
# 3   Ciro Aristizabal           Francisco Samuel
# 4   Rendón Felizzola                   Isabella
# 5             Posada           Manuela  Arevalo
# 6             Ubilla  Maribel Antonella Ramirez
# 7    Chávez González               María Camila
# 8               Ríos        María José Martínez
# 9   Roncancio Osorio                       Sara
# 10              Rozo             Sarah  Fajardo
#
#                  Dirección de correo February 8th, 2024 - Day 1  \
# 0                                NaN                10 feb 2024
# 1                                NaN                      100.0
# 2        ainhoa.larez@renfort.edu.co                        NaN
# 3         samuel.ciro@renfort.edu.co                       90.0
# ...
